# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-97ed2218-d461-4c2e-98e7-be72157d1ab5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97ed2218-d461-4c2e-98e7-be72157d1ab5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

for filename in uploaded.keys():
    df = pd.read_csv(filename)

df.head()
# Out:
#   EventID                  EventName            Department  StudentYear  \
# 0    E001  Entrepreneurship Workshop                   CSE            2
# 1    E002        Photography Contest                   MBA            1
# 2    E003           Quiz Competition               Science            3
# 3    E004        Photography Contest  Training & Placement            3
# 4    E005                Alumni Meet                  Arts            1
#
#    FeedbackRating  Usefulness  OrganizationQuality  SpeakerQuality  \
# 0               3           5                    3               3
# 1               5           4                    4               3
# 2               3           4                    5               4
# 3               5           4                    5               4
# 4               5           3                    4               4
#
#                       Suggestions  Attendance
# 0     Very helpful for interviews         191
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EventID              259 non-null    object
#  1   EventName            259 non-null    object
#  2   Department           259 non-null    object
#  3   StudentYear          259 non-null    int64
#  4   FeedbackRating       259 non-null    int64
#  5   Usefulness           259 non-null    int64
#  6   OrganizationQuality  259 non-null    int64
#  7   SpeakerQuality       259 non-null    int64
#  8   Suggestions          259 non-null    object
#  9   Attendance           259 non-null    int64
# dtypes: int64(6), object(4)
# memory usage: 20.4+ KB
# EventID                0
# EventName              0
# Department             0
# StudentYear            0
# FeedbackRating         0
# Usefulness             0
# OrganizationQuality    0
# SpeakerQuality         0
# ...

# %%
df = df.drop_duplicates()

df = df.dropna()

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Detect categorical columns automatically
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    plt.figure(figsize=(8,5))
    # Count values for each category
    counts = df[col].value_counts()
    sns.barplot(x=counts.index, y=counts.values, palette='viridis')
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipython-input-1520875271.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='viridis')
# /tmp/ipython-input-1520875271.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='viridis')
# /tmp/ipython-input-1520875271.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, palette='viridis')
# /tmp/ipython-input-1520875271.py:11: FutureWarning:
#
# ...

# %%
for col in categorical_cols:
    plt.figure(figsize=(6,6))
    df[col].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel'))
    plt.title(f'Pie Chart of {col}')
    plt.ylabel('')  # Hide y-label
    plt.show()

# %%
import matplotlib.pyplot as plt

# Use first numeric column for demonstration
numeric_cols = df.select_dtypes(include='number').columns
if len(numeric_cols) > 0:
    plt.figure(figsize=(8,4))
    plt.plot(df[numeric_cols[0]], marker='o', linestyle='-', color='blue')
    plt.title(f'Line Chart of {numeric_cols[0]}')
    plt.xlabel('Index')
    plt.ylabel(numeric_cols[0])
    plt.show()

# %%
if len(categorical_cols) > 0:
    counts = df[categorical_cols[0]].value_counts()
    plt.figure(figsize=(6,4))
    counts.plot(kind='barh', color='orange')
    plt.title(f'Horizontal Bar Chart of {categorical_cols[0]}')
    plt.xlabel('Count')
    plt.ylabel(categorical_cols[0])
    plt.show()
